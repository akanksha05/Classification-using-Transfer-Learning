# %% [markdown]
# ## Importing Libraries

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
# pip install scikit-learn

# %%
# !pip install hypopt

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# import tensorflow.compat.v1 as tf
# tf.disable_v2_behavior()
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
 
# Importing sklearn libraries
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
 
# Importing hypopt library for grid search
from hypopt import GridSearch
 
# Importing Keras libraries
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import imagenet_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, GlobalAveragePooling2D
 
import warnings
warnings.filterwarnings('ignore')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
##Mounting Drive (only for colab. Not required on local machine)
# from google.colab import drive



# drive.mount('/content/gdrive', force_remount=True)
# root_dir = "/"

# %% [markdown]
# # Setting Paths for Train,Validation and Test Datasets

# %%
root_dir = 'E:/Github/flower-classification/Classification-using-Transfer-Learning/data'

PATH = os.path.join(root_dir, 'SplitDataset')

# %%
train_dir = os.path.join(PATH,'train')
validation_dir = os.path.join(PATH,'val')
test_dir = os.path.join(PATH,'test')

#Creating Category Labels

train_labels = []
validation_labels = []
test_labels = []

# %% [markdown]
# # Creating Label Data

# %%
for idx_cat,i in enumerate(os.listdir(train_dir)):
    train_files = train_dir+'/'+i
    for train_idx,j in enumerate(os.listdir(train_files)):
            train_labels.append(idx_cat)

# %%
for idx_cat,i in enumerate(os.listdir(validation_dir)):
    val_files = validation_dir+'/'+i
    for val_idx,j in enumerate(os.listdir(val_files)):
        validation_labels.append(idx_cat)

# %%
for idx_cat,i in enumerate(os.listdir(test_dir)):
    test_files = test_dir+'/'+i
    for train_idx,j in enumerate(os.listdir(test_files)):
        test_labels.append(idx_cat)

# %%
# list(set(New_train_labels))
img_width, img_height = 224, 224

# %% [markdown]
# ## Display some pictures

# %%
# Show pictures
import os, random
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image
# from PIL import Image

def show_pictures(path):
    random_img = random.choice(os.listdir(path))
    img_path = os.path.join(path, random_img)

    img = image.load_img(img_path, target_size=(img_width, img_height))
    img_tensor = image.img_to_array(img)  # Image data encoded as integers in the 0–255 range
    img_tensor /= 255.  # Normalize to [0,1] for plt.imshow application
    plt.imshow(img_tensor)
    plt.show()

# %%
# pip install Pillow

# %%
# import sys
# from PIL import Image
# sys.modules['Image'] = Image

# %%
# import Image
# print(Image.__file__)

# %%
# from PIL import Image
# # print(Image.__file__)

# %%
for i in (os.listdir(train_dir)):
  train_files = train_dir+'/'+i
  print(i)
  for i in range(0,2):
       show_pictures(train_files)
# Out:
# daisy
# dandelion
# rose
# sunflower
# tulip

# %% [markdown]
# # VGG16 models after removing different layers

# %% [markdown]
# # 1 ) without removing any layer

# %%
#Defining the Model VGG16
from tensorflow.keras.models import load_model
from tensorflow.keras import models
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten

image_input = Input(shape=(224, 224, 3))
VGG16_model1 = VGG16(input_tensor=image_input, include_top=True,weights='imagenet')
VGG16_model1.summary()
for layer in VGG16_model1.layers:
  layer.trainable = False
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# # 2) Model after popping last dense layer

# %%
VGG16_model1.layers.pop() 
VGG16_model2 = Model(VGG16_model1.input, VGG16_model1.layers[-2].output)
VGG16_model2.summary()

for layer in VGG16_model2.layers:
  layer.trainable = False
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# # 3) Model popping Last Fully Connected layer

# %%
VGG16_model2.layers.pop() 
VGG16_model3 = Model(VGG16_model2.input, VGG16_model2.layers[-2].output)
VGG16_model3.summary()


for layer in VGG16_model3.layers:
  layer.trainable = False
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# # 4) Model popping second last Fully Connected layer

# %%
for layer in VGG16_model3.layers:
  layer.trainable = False

VGG16_model3.layers.pop() 
VGG16_model4 = Model(VGG16_model3.input, VGG16_model3.layers[-2].output)
VGG16_model4.summary()

for layer in VGG16_model4.layers:
  layer.trainable = False
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# # Feature Extraction Code

# %%
#Extracting the feature Extraction

import tensorflow.keras as keras

from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image

def images_to_array(dataset_dir,model):
 
        dataset_array = []
        
        classes_names = os.listdir(dataset_dir)

        for current_class_name in classes_names:
            class_dir = os.path.join(dataset_dir, current_class_name)
            images_in_class = os.listdir(class_dir)
            #print("Class index", class_counter, ", ", current_class_name, ":" , len(images_in_class))

            for image_file in images_in_class:
                     if image_file.endswith(".jpg"):
                        image_file_dir = os.path.join(class_dir, image_file)
                        img = keras.preprocessing.image.load_img(image_file_dir, target_size=(224, 224))
                        img_array = keras.preprocessing.image.img_to_array(img)
                        img_data = np.expand_dims(img_array, axis=0)
                        img_data = preprocess_input(img_data)
                        VGG16_feature = model.predict(img_data)
                        VGG16_feature_np = VGG16_feature.flatten()
                        dataset_array.append(VGG16_feature_np)
                        dataset_array_model = np.array(dataset_array)
                        dataset_array_model.shape

        return dataset_array_model

# %% [markdown]
# # Extracting Features for VGG16 models

# %%
#Without popping any layer for VGG16
train_dataset_array1_VGG16 = images_to_array(dataset_dir=train_dir,model = VGG16_model1)
val_dataset_array1_VGG16 = images_to_array(dataset_dir=validation_dir,model = VGG16_model1)
test_dataset_array1_VGG16 = images_to_array(dataset_dir=test_dir,model = VGG16_model1)
print("Training Data Array Shape :", len(train_dataset_array1_VGG16))
print("Validation Data Array Shape :", len(val_dataset_array1_VGG16))
print("Test Data Array Shape :", len(test_dataset_array1_VGG16))
# Out:
# Training Data Array Shape : 2592
# Validation Data Array Shape : 861
# Test Data Array Shape : 870

# %%
#With popping first layer
train_dataset_array2_VGG16 = images_to_array(dataset_dir=train_dir,model = VGG16_model2)
val_dataset_array2_VGG16 = images_to_array(dataset_dir=validation_dir,model = VGG16_model2)
test_dataset_array2_VGG16 = images_to_array(dataset_dir=test_dir,model = VGG16_model2)
print("Training Data Array Shape :", len(train_dataset_array2_VGG16))
print("Validation Data Array Shape :", len(val_dataset_array2_VGG16))
print("Test Data Array Shape :", len(test_dataset_array2_VGG16))
# Out:
# Training Data Array Shape : 2592
# Validation Data Array Shape : 861
# Test Data Array Shape : 870

# %%
#With popping Second layer
train_dataset_array3_VGG16 = images_to_array(dataset_dir=train_dir,model = VGG16_model3)
val_dataset_array3_VGG16 = images_to_array(dataset_dir=validation_dir,model = VGG16_model3)
test_dataset_array3_VGG16 = images_to_array(dataset_dir=test_dir,model = VGG16_model3)
print("Training Data Array Shape :", len(train_dataset_array3_VGG16))
print("Validation Data Array Shape :", len(val_dataset_array3_VGG16))
print("Test Data Array Shape :", len(test_dataset_array3_VGG16))
# Out:
# Training Data Array Shape : 2592
# Validation Data Array Shape : 861
# Test Data Array Shape : 870

# %%
#With popping Third layer
train_dataset_array4_VGG16 = images_to_array(dataset_dir=train_dir,model = VGG16_model4)
val_dataset_array4_VGG16 = images_to_array(dataset_dir=validation_dir,model = VGG16_model4)
test_dataset_array4_VGG16 = images_to_array(dataset_dir=test_dir,model = VGG16_model4)
print("Training Data Array Shape :", len(train_dataset_array4_VGG16))
print("Validation Data Array Shape :", len(val_dataset_array4_VGG16))
print("Test Data Array Shape :", len(test_dataset_array4_VGG16))
# Out:
# Training Data Array Shape : 2592
# Validation Data Array Shape : 861
# Test Data Array Shape : 870

# %% [markdown]
# # Saving extracted features of VGG16

# %%
saving_path = os.path.join(root_dir, 'SavedFeatures/VGG16')

# %%
import numpy as np
np.save(os.path.join(saving_path,'train-features-0layer'), train_dataset_array1_VGG16)
np.save(os.path.join(saving_path,'train-labels-0layer'), train_labels)

np.save(os.path.join(saving_path,'val-features-0layer'), val_dataset_array1_VGG16)
np.save(os.path.join(saving_path,'val-labels-0layer'), validation_labels)

np.save(os.path.join(saving_path,'test-features-0layer'), test_dataset_array1_VGG16)
np.save(os.path.join(saving_path,'test-labels-0layer'), test_labels)

# %%
import numpy as np
np.save(os.path.join(saving_path,'train-features-1layer'), train_dataset_array2_VGG16)
np.save(os.path.join(saving_path,'val-features-1layer'), val_dataset_array2_VGG16)
np.save(os.path.join(saving_path,'test-features-1layer'), test_dataset_array2_VGG16)

# %%
import numpy as np
np.save(os.path.join(saving_path,'train-features-2layer'), train_dataset_array3_VGG16)
np.save(os.path.join(saving_path,'val-features-2layer'), val_dataset_array3_VGG16)
np.save(os.path.join(saving_path,'test-features-2layer'), test_dataset_array3_VGG16)

# %%
import numpy as np
np.save(os.path.join(saving_path,'train-features-3layer'), train_dataset_array4_VGG16)
np.save(os.path.join(saving_path,'val-features-3layer'), val_dataset_array4_VGG16)
np.save(os.path.join(saving_path,'test-features-3layer'), test_dataset_array4_VGG16)

# %% [markdown]
# ## Use the saved extracted features of VGG16

# %%
#Access the Features
import numpy as np
#np.load("/content/gdrive/My Drive/VGG16_Features/No_Layer_Removed/train-features-VGG16-0layer.npy")
train_dataset_array1_VGG16 = np.load(os.path.join(saving_path,'train-features-0layer.npy'))
train_labels = np.load(os.path.join(saving_path,'train-labels-0layer.npy'))

val_dataset_array1_VGG16 = np.load(os.path.join(saving_path,'val-features-0layer.npy'))
validation_labels = np.load(os.path.join(saving_path,'val-labels-0layer.npy'))

test_dataset_array1_VGG16 = np.load(os.path.join(saving_path,'test-features-0layer.npy'))
test_labels = np.load(os.path.join(saving_path,'test-labels-0layer.npy'))

# %%
train_dataset_array2_VGG16 = np.load(os.path.join(saving_path,'train-features-1layer.npy'))
val_dataset_array2_VGG16 = np.load(os.path.join(saving_path,'val-features-1layer.npy'))
test_dataset_array2_VGG16 = np.load(os.path.join(saving_path,'test-features-2layer.npy'))

# %%
train_dataset_array3_VGG16 = np.load(os.path.join(saving_path,'train-features-2layer.npy'))
val_dataset_array3_VGG16 = np.load(os.path.join(saving_path,'val-features-2layer.npy'))
test_dataset_array3_VGG16 = np.load(os.path.join(saving_path,'test-features-2layer.npy'))

# %%
train_dataset_array4_VGG16 = np.load(os.path.join(saving_path,'train-features-3layer.npy'))
val_dataset_array4_VGG16 = np.load(os.path.join(saving_path,'val-features-3layer.npy'))
test_dataset_array4_VGG16 = np.load(os.path.join(saving_path,'test-features-3layer.npy'))

# %% [markdown]
# ## Creating Final Extracted Features and Target Labels

# %%
#Clubbing Features
train_dataset_array1_VGG16 = np.concatenate((train_dataset_array1_VGG16, val_dataset_array1_VGG16))
train_dataset_array2_VGG16= np.concatenate((train_dataset_array2_VGG16, val_dataset_array2_VGG16))
train_dataset_array3_VGG16 = np.concatenate((train_dataset_array3_VGG16, val_dataset_array3_VGG16))
train_dataset_array4_VGG16 = np.concatenate((train_dataset_array4_VGG16, val_dataset_array4_VGG16))
train_labels = np.concatenate((train_labels, validation_labels))
# train_dataset_array1_VGG16.shape

# %% [markdown]
# # PCA

# %%
#############################################################################################
#           To be used only when the extracted features are too big 
#           PCA cn be used to reduce the the dimension of features

#############################################################################################


from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit on training set only.

train_dataset_array1_VGG16 = scaler.fit_transform(train_dataset_array1_VGG16)
train_dataset_array2_VGG16 = scaler.fit_transform(train_dataset_array2_VGG16)
train_dataset_array3_VGG16 = scaler.fit_transform(train_dataset_array3_VGG16)
train_dataset_array4_VGG16 = scaler.fit_transform(train_dataset_array4_VGG16)


# # # Apply transform to both the training set and the test set.


# train_dataset_array1_VGG16 = scaler.transform(train_dataset_array1_VGG16)
test_dataset_array1_VGG16 = scaler.fit_transform(test_dataset_array1_VGG16)

# train_dataset_array2_VGG16 = scaler.transform(train_dataset_array2_VGG16)
test_dataset_array2_VGG16 = scaler.fit_transform(test_dataset_array2_VGG16)

# train_dataset_array3_VGG16 = scaler.transform(train_dataset_array3_VGG16)
test_dataset_array3_VGG16 = scaler.fit_transform(test_dataset_array3_VGG16)

# train_dataset_array4_VGG16 = scaler.transform(train_dataset_array4_VGG16)
test_dataset_array4_VGG16 = scaler.fit_transform(test_dataset_array4_VGG16)

# %%
from sklearn.decomposition import PCA
pca = PCA(.95)


train_dataset_array1_VGG16 = pca.fit_transform(train_dataset_array1_VGG16)
train_dataset_array2_VGG16 = pca.fit_transform(train_dataset_array2_VGG16)
train_dataset_array3_VGG16 = pca.fit_transform(train_dataset_array2_VGG16)
train_dataset_array4_VGG16 = pca.fit_transform(train_dataset_array4_VGG16)


# Apply transform to both the training set and the test set.



# train_dataset_array1_VGG16 = pca.transform(train_dataset_array1_VGG16)
test_dataset_array1_VGG16 = pca.fit_transform(test_dataset_array1_VGG16)

# train_dataset_array2_VGG16 = pca.transform(train_dataset_array2_VGG16)
test_dataset_array2_VGG16 = pca.fit_transform(test_dataset_array2_VGG16)

# train_dataset_array3_VGG16 = pca.transform(train_dataset_array3_VGG16)
test_dataset_array3_VGG16 = pca.fit_transform(test_dataset_array3_VGG16)

# train_dataset_array4_VGG16 = pca.transform(train_dataset_array4_VGG16)
test_dataset_array4_VGG16 = pca.fit_transform(test_dataset_array4_VGG16)

# %% [markdown]
# #

# %% [markdown]
# ## Applying SVM Classifier on extracted models Features

# %%
#Implementing Classifier SVM
import sklearn
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.svm import SVC
# import sklearn.external as extjoblib
import joblib
from sklearn import svm, metrics, datasets

# %%
#Without removing any layer
def SVM_Classifier(train_dataset_array,New_train_labels,test_dataset_array):
      param_grid = [
        {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
        {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
      ]
      svc = svm.SVC()
      clf = GridSearchCV(svc, param_grid, refit = True, verbose = 3, n_jobs=-1)
      clf.fit(train_dataset_array,New_train_labels)
      y_predict_svm = clf.predict(test_dataset_array)
      return y_predict_svm

# %%
# train_dataset_array1_VGG16.shape

# %%
# np.shape(train_labels)

# %%
y_predict_svm1_VGG16 = SVM_Classifier(train_dataset_array1_VGG16,train_labels,test_dataset_array1_VGG16)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.9min finished

# %%
np.save('data/Classifier_results/y_predict_svm1_VGG16.npy',y_predict_svm1_VGG16)

# %%
y_predict_svm2_VGG16 = SVM_Classifier(train_dataset_array2_VGG16,train_labels,test_dataset_array2_VGG16)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 14.8min finished

# %%
np.save('data/Classifier_results/y_predict_svm2_VGG16.npy',y_predict_svm2_VGG16)

# %%
y_predict_svm3_VGG16 = SVM_Classifier(train_dataset_array3_VGG16,train_labels,test_dataset_array3_VGG16)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 21.3min finished

# %%
np.save('data/Classifier_results/y_predict_svm3_VGG16.npy',y_predict_svm3_VGG16)

# %%
y_predict_svm4_VGG16 = SVM_Classifier(train_dataset_array4_VGG16,train_labels,test_dataset_array4_VGG16)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.

# %%
np.save('data/Classifier_results/y_predict_svm4_VGG16.npy',y_predict_svm4_VGG16)

# %%
y_predict_svm1_VGG16 = np.load('data/Classifier_results/y_predict_svm1_VGG16.npy')
y_predict_svm2_VGG16 = np.load('data/Classifier_results/y_predict_svm2_VGG16.npy')
y_predict_svm3_VGG16 = np.load('data/Classifier_results/y_predict_svm3_VGG16.npy')
y_predict_svm4_VGG16 = np.load('data/Classifier_results/y_predict_svm4_VGG16.npy')

# %% [markdown]
# ## Applying Random Forest Classifier on extracted model Features

# %%
def RF_Classifier(train_dataset_array,train_labels,test_dataset_array):
    #Import Random Forest Model
    from sklearn.ensemble import RandomForestClassifier

    #Create a Gaussian Classifier
    clf=RandomForestClassifier(n_estimators=100, n_jobs=-1)

    #Train the model using the training sets y_pred=clf.predict(X_test)
    clf.fit(train_dataset_array, train_labels)

    y_predict = clf.predict(test_dataset_array)
    return y_predict

# %%
y_predict_rf1_VGG16 = RF_Classifier(train_dataset_array1_VGG16,train_labels,test_dataset_array1_VGG16)

# %%
np.save("data/Classifier_results/y_predict_rf1_VGG16.npy",y_predict_rf1_VGG16)

# %%
y_predict_rf2_VGG16 = RF_Classifier(train_dataset_array2_VGG16,train_labels,test_dataset_array2_VGG16)

# %%
np.save("data/Classifier_results/y_predict_rf2_VGG16.npy",y_predict_rf2_VGG16)

# %%
y_predict_rf3_VGG16 = RF_Classifier(train_dataset_array3_VGG16,train_labels,test_dataset_array3_VGG16)

# %%
np.save("data/Classifier_results/y_predict_rf3_VGG16.npy",y_predict_rf3_VGG16)

# %%
y_predict_rf4_VGG16 = RF_Classifier(train_dataset_array4_VGG16,train_labels,test_dataset_array4_VGG16)

# %%
np.save("data/Classifier_results/y_predict_rf4_VGG16.npy",y_predict_rf4_VGG16)

# %%
y_predict_rf1_VGG16 = np.load('data/Classifier_results/y_predict_rf1_VGG16.npy')
y_predict_rf2_VGG16 = np.load('data/Classifier_results/y_predict_rf2_VGG16.npy')
y_predict_rf3_VGG16 = np.load('data/Classifier_results/y_predict_rf3_VGG16.npy')
y_predict_rf4_VGG16 = np.load('data/Classifier_results/y_predict_rf4_VGG16.npy')

# %% [markdown]
# ## Applying XGBoost Classifier on extracted model Features

# %%
# pip install xgboost

# %%
def XGBoost_Classifier(train_dataset_array, New_train_labels,test_dataset_array):
  #XGBoost
  from numpy import loadtxt
  from xgboost import XGBClassifier

  # fit model no training data
  model = XGBClassifier( learning_rate =0.1,
              n_estimators=1000,
              max_depth=5,
              min_child_weight=1,
              gamma=0,
              subsample=0.8,
              colsample_bytree=0.8,
              objective= 'binary:logistic',
              nthread=4,
              scale_pos_weight=1,
              seed=27,
              n_jobs=-1)
 
  #model=XGBClassifier()
  model.fit(train_dataset_array, New_train_labels)
  y_predict = model.predict(test_dataset_array)
  return y_predict

# %%
y_predict_xg1_VGG16 = XGBoost_Classifier(train_dataset_array1_VGG16, train_labels,test_dataset_array1_VGG16)

# %%
np.save("data/Classifier_results/y_predict_xg1_VGG16.npy",y_predict_xg1_VGG16)

# %%
y_predict_xg2_VGG16 = XGBoost_Classifier(train_dataset_array2_VGG16, train_labels,test_dataset_array2_VGG16)

# %%
np.save("data/Classifier_results/y_predict_xg2_VGG16.npy",y_predict_xg2_VGG16)

# %%
y_predict_xg3_VGG16 = XGBoost_Classifier(train_dataset_array3_VGG16, train_labels,test_dataset_array3_VGG16)

# %%
np.save("data/Classifier_results/y_predict_xg3_VGG16.npy",y_predict_xg3_VGG16)

# %%
y_predict_xg4_VGG16 = XGBoost_Classifier(train_dataset_array4_VGG16, train_labels,test_dataset_array4_VGG16)

# %%
np.save("data/Classifier_results/y_predict_xg4_VGG16.npy",y_predict_xg4_VGG16)

# %%
y_predict_xg1_VGG16 = np.load('data/Classifier_results/y_predict_xg1_VGG16.npy')
y_predict_xg2_VGG16 = np.load('data/Classifier_results/y_predict_xg2_VGG16.npy')
y_predict_xg3_VGG16 = np.load('data/Classifier_results/y_predict_xg3_VGG16.npy')
y_predict_xg4_VGG16 = np.load('data/Classifier_results/y_predict_xg4_VGG16.npy')

# %% [markdown]
# ## Applying Naive Bayes Classifier on extracted model Features

# %%
def NB_Classifier(train_dataset_array,train_labels,test_dataset_array):
  #Import Gaussian Naive Bayes model
  from sklearn.naive_bayes import GaussianNB

  #Create a Gaussian Classifier
  model = GaussianNB()

  # Train the model using the training sets
  model.fit(train_dataset_array,train_labels)
  y_predict = model.predict(test_dataset_array)
  return y_predict

# %%
y_predict_NB1_VGG16 = NB_Classifier(train_dataset_array1_VGG16,train_labels,test_dataset_array1_VGG16)

# %%
np.save("data/Classifier_results/y_predict_NB1_VGG16.npy",y_predict_NB1_VGG16)

# %%
y_predict_NB2_VGG16 = NB_Classifier(train_dataset_array2_VGG16,train_labels,test_dataset_array2_VGG16)

# %%
np.save("data/Classifier_results/y_predict_NB2_VGG16.npy",y_predict_NB2_VGG16)

# %%
y_predict_NB3_VGG16 = NB_Classifier(train_dataset_array3_VGG16,train_labels,test_dataset_array3_VGG16)

# %%
np.save("data/Classifier_results/y_predict_NB3_VGG16.npy",y_predict_NB3_VGG16)

# %%
y_predict_NB4_VGG16 = NB_Classifier(train_dataset_array4_VGG16,train_labels,test_dataset_array4_VGG16)

# %%
np.save("data/Classifier_results/y_predict_NB4_VGG16.npy",y_predict_NB4_VGG16)

# %%
y_predict_NB1_VGG16 = np.load('data/Classifier_results/y_predict_NB1_VGG16.npy')
y_predict_NB2_VGG16 = np.load('data/Classifier_results/y_predict_NB2_VGG16.npy')
y_predict_NB3_VGG16 = np.load('data/Classifier_results/y_predict_NB3_VGG16.npy')
y_predict_NB4_VGG16 = np.load('data/Classifier_results/y_predict_NB4_VGG16.npy')

# %% [markdown]
# ## Applying Bayesian Ridge Classifier on extracted model Features

# %%
def Ridge_Classifier(train_dataset_array, New_train_labels,test_dataset_array):
  from sklearn import linear_model
  from sklearn.linear_model import RidgeClassifier
  clf = RidgeClassifier().fit(train_dataset_array, New_train_labels)
  y_pred_br = clf.predict(test_dataset_array)
  return y_pred_br

# %%
y_predict_Ridge1_VGG16 = Ridge_Classifier(train_dataset_array1_VGG16, New_train_labels,test_dataset_array1_VGG16)
y_predict_Ridge2_VGG16 = Ridge_Classifier(train_dataset_array2_VGG16, New_train_labels,test_dataset_array2_VGG16)
y_predict_Ridge3_VGG16 = Ridge_Classifier(train_dataset_array3_VGG16, New_train_labels,test_dataset_array3_VGG16)
y_predict_Ridge4_VGG16 = Ridge_Classifier(train_dataset_array4_VGG16, New_train_labels,test_dataset_array4_VGG16)

# %%
np.save("data/Classifier_results/y_predict_Ridge1_VGG16.npy",y_predict_Ridge1_VGG16)
np.save("data/Classifier_results/y_predict_Ridge2_VGG16.npy",y_predict_Ridge2_VGG16)
np.save("data/Classifier_results/y_predict_Ridge3_VGG16.npy",y_predict_Ridge3_VGG16)
np.save("data/Classifier_results/y_predict_Ridge4_VGG16.npy",y_predict_Ridge4_VGG16)

# %%
y_predict_Ridge1_VGG16 = np.load('data/Classifier_results/y_predict_Ridge1_VGG16.npy')
y_predict_Ridge2_VGG16 = np.load('data/Classifier_results/y_predict_Ridge2_VGG16.npy')
y_predict_Ridge3_VGG16 = np.load('data/Classifier_results/y_predict_Ridge3_VGG16.npy')
y_predict_Ridge4_VGG16 = np.load('data/Classifier_results/y_predict_Ridge4_VGG16.npy')

# %%
pip install PrettyTable

# %% [markdown]
# ## Displaying Tabular Results for Accuracy

# %%
from prettytable import PrettyTable
print("\nVGG16(Accuracy):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(accuracy_score(test_labels,y_predict_svm1_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_rf1_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_xg1_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_NB1_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_Ridge1_VGG16))])
t.add_row([1, "{:.2%}".format(accuracy_score(test_labels,y_predict_svm2_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_rf2_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_xg2_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_NB2_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_Ridge2_VGG16))])
t.add_row([2, "{:.2%}".format(accuracy_score(test_labels,y_predict_svm3_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_rf3_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_xg3_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_NB3_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_Ridge3_VGG16))])
t.add_row([3, "{:.2%}".format(accuracy_score(test_labels,y_predict_svm4_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_rf4_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_xg4_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_NB4_VGG16)),"{:.2%}".format(accuracy_score(test_labels,y_predict_Ridge4_VGG16))])
print(t)

# %%
from prettytable import PrettyTable
print("\nInceptionV3(Accuracy):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(accuracy_score(test_labels,y_predict_svm1_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_rf1_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_xg1_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_NB1_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_Ridge1_InceptionV3))])
t.add_row([1, "{:.2%}".format(accuracy_score(test_labels,y_predict_svm2_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_rf2_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_xg2_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_NB2_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_Ridge2_InceptionV3))])
t.add_row([2, "{:.2%}".format(accuracy_score(test_labels,y_predict_svm3_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_rf3_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_xg3_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_NB3_InceptionV3)),"{:.2%}".format(accuracy_score(test_labels,y_predict_Ridge3_InceptionV3))])
print(t)

# %% [markdown]
# ## Displaying Tabular Results for Precision

# %%
from sklearn.metrics import precision_score
print("\nVGG16(Precision):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(precision_score(test_labels,y_predict_svm1_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_rf1_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_xg1_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_NB1_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_Ridge1_VGG16, average='macro'))])
t.add_row([1, "{:.2%}".format(precision_score(test_labels,y_predict_svm2_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_rf2_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_xg2_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_NB2_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_Ridge2_VGG16, average='macro'))])
t.add_row([2, "{:.2%}".format(precision_score(test_labels,y_predict_svm3_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_rf3_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_xg3_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_NB3_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_Ridge3_VGG16, average='macro'))])
t.add_row([3, "{:.2%}".format(precision_score(test_labels,y_predict_svm4_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_rf4_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_xg4_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_NB4_VGG16, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_Ridge4_VGG16, average='macro'))])
print(t)

# %%
from sklearn.metrics import precision_score
print("\nInceptionV3(Precision):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(precision_score(test_labels,y_predict_svm1_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_rf1_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_xg1_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_NB1_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_Ridge1_InceptionV3, average='macro'))])
t.add_row([1, "{:.2%}".format(precision_score(test_labels,y_predict_svm2_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_rf2_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_xg2_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_NB2_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_Ridge2_InceptionV3, average='macro'))])
t.add_row([2, "{:.2%}".format(precision_score(test_labels,y_predict_svm3_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_rf3_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_xg3_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_NB3_InceptionV3, average='macro')),"{:.2%}".format(precision_score(test_labels,y_predict_Ridge3_InceptionV3, average='macro'))])
print(t)

# %% [markdown]
# ## Displaying Tabular Results for Recall

# %%
from sklearn.metrics import recall_score
print("\nVGG16(Recall):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(recall_score(test_labels, y_predict_svm1_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_rf1_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_xg1_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_NB1_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_Ridge1_VGG16, average='macro'))])
t.add_row([1, "{:.2%}".format(recall_score(test_labels, y_predict_svm2_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_rf2_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_xg2_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_NB2_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_Ridge2_VGG16, average='macro'))])
t.add_row([2, "{:.2%}".format(recall_score(test_labels, y_predict_svm3_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_rf3_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_xg3_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_NB3_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_Ridge3_VGG16, average='macro'))])
t.add_row([3, "{:.2%}".format(recall_score(test_labels, y_predict_svm4_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_rf4_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_xg4_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_NB4_VGG16, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_Ridge4_VGG16, average='macro'))])
print(t)

# %%
from sklearn.metrics import recall_score
print("\nInceptionV3(Recall):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(recall_score(test_labels, y_predict_svm1_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_rf1_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_xg1_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_NB1_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_Ridge1_InceptionV3, average='macro'))])
t.add_row([1, "{:.2%}".format(recall_score(test_labels, y_predict_svm2_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_rf2_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_xg2_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_NB2_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_Ridge2_InceptionV3, average='macro'))])
t.add_row([2, "{:.2%}".format(recall_score(test_labels, y_predict_svm3_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_rf3_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_xg3_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_NB3_InceptionV3, average='macro')),"{:.2%}".format(recall_score(test_labels, y_predict_Ridge3_InceptionV3, average='macro'))])
print(t)

# %% [markdown]
# ## Displaying Tabular Results for F1 Score

# %%
from sklearn.metrics import f1_score
print("\nVGG16(F1 Score):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(f1_score(test_labels, y_predict_svm1_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_rf1_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_xg1_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_NB1_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_Ridge1_VGG16, average='macro'))])
t.add_row([1, "{:.2%}".format(f1_score(test_labels, y_predict_svm2_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_rf2_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_xg2_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_NB2_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_Ridge2_VGG16, average='macro'))])
t.add_row([2, "{:.2%}".format(f1_score(test_labels, y_predict_svm3_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_rf3_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_xg3_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_NB3_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_Ridge3_VGG16, average='macro'))])
t.add_row([3, "{:.2%}".format(f1_score(test_labels, y_predict_svm4_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_rf4_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_xg4_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_NB4_VGG16, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_Ridge4_VGG16, average='macro'))])
print(t)

# %%
from sklearn.metrics import f1_score
print("\nInceptionV3(F1 Score):")
t = PrettyTable(['Removed Layer','SVM', 'Random Forest','XGBoost','Naive Bayes','Bayesian Ridge Regression'])
t.add_row([0, "{:.2%}".format(f1_score(test_labels, y_predict_svm1_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_rf1_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_xg1_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_NB1_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_Ridge1_InceptionV3, average='macro'))])
t.add_row([1, "{:.2%}".format(f1_score(test_labels, y_predict_svm2_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_rf2_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_xg2_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_NB2_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_Ridge2_InceptionV3, average='macro'))])
t.add_row([2, "{:.2%}".format(f1_score(test_labels, y_predict_svm3_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_rf3_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_xg3_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_NB3_InceptionV3, average='macro')),"{:.2%}".format(f1_score(test_labels, y_predict_Ridge3_InceptionV3, average='macro'))])
print(t)
